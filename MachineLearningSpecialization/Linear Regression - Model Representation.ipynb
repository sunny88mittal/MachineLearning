# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - We will create a single varibale model for linear regression f(x) = wx + b
# - We will use hosuing example where x will be (size of house in sqft)/1000 and y will be price of house in USD/1000

# %%
x_train = np.array([1.0,2.0]) # House sizes size/1000
y_train = np.array([300,500]) # House prizes price/1000 USD

print (f"x_train = {x_train}")
print (f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300 500]

# %%
m = x_train.shape[0]
print(m)
# Out:
# 2

# %%
# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r')
# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.show()

# %%
# Computing the cost function with w and b
w = 200
b = 100

# %%
# Define the compute function
def compute_model_output(x,w,b) :
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w*x[i] +b
    return f_wb

# %%
tmp_f_wb = compute_model_output(x_train, w, b,)

# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b',label='Our Prediction')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')

# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %%
#Predict the price with the model with w=200, b=100   
x_i = 1.2
cost_1200sqft = w * x_i + b    

print(f"${cost_1200sqft:.0f} thousand dollars")
# Out:
# $340 thousand dollars
